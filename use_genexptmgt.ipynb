# %%
from gen_experimentmgt import experiment_entry

# %%
p1_list = [1, 2, 3]
p2_list = [1, 2]
p3_list = [1, 2, 3, 4]

@experiment_entry(p1=p1_list, p2=p2_list, p3=p3_list)
def model1(p1, p2, p3):
    return p1 + p2 + p3

model1()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b24e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b24e_level0_col0" class="col_heading level0 col0" >p1</th>
#       <th id="T_8b24e_level0_col1" class="col_heading level0 col1" >p2</th>
#       <th id="T_8b24e_level0_col2" class="col_heading level0 col2" >p3</th>
#       <th id="T_8b24e_level0_col3" class="col_heading level0 col3" >Model Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b24e_level0_row0" class="row_heading level0 row0" >Experiment 1:</th>
#       <td id="T_8b24e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8b24e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_8b24e_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_8b24e_row0_col3" class="data row0 col3" ><span style="background-color: yellow">3</span></td>
#     </tr>
#     <tr>
# ...

# %%
p1 = ["A", "B", "C"]
p2 = ["D"]

@experiment_entry(p1=p1, p2=p2)
def model2(p1, p2):
    return p1 + p2

model2()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d7451">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7451_level0_col0" class="col_heading level0 col0" >p1</th>
#       <th id="T_d7451_level0_col1" class="col_heading level0 col1" >p2</th>
#       <th id="T_d7451_level0_col2" class="col_heading level0 col2" >Model Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7451_level0_row0" class="row_heading level0 row0" >Experiment 1:</th>
#       <td id="T_d7451_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_d7451_row0_col1" class="data row0 col1" >D</td>
#       <td id="T_d7451_row0_col2" class="data row0 col2" ><span style="background-color: yellow">AD</span></td>
#     </tr>
#     <tr>
#       <th id="T_d7451_level0_row1" class="row_heading level0 row1" >Experiment 2:</th>
#       <td id="T_d7451_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_d7451_row1_col1" class="data row1 col1" >D</td>
# ...
